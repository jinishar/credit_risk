# %% [markdown]
# # Home Credit Default Risk — Exploratory Data Analysis
#
# Reuses the functions in `eda.py` so the notebook and the script stay in sync.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

from notebooks.eda import (
    dataset_summary, feature_categorization, data_quality, business_insights,
)
from src.data.loader import load_train_df

df = load_train_df()
df.shape

# %% [markdown]
# ## 1. Dataset Summary

# %%
dataset_summary(df)

# %% [markdown]
# ## 2. Feature Categorization

# %%
groups = feature_categorization(df)

# %% [markdown]
# ## 3. Data Quality / Missing Values

# %%
missing = data_quality(df)

# %% [markdown]
# ## 4. Business Insights (>=5, with charts)
#
# Figures are also saved to `notebooks/figures/` by this same call.

# %%
business_insights(df)
